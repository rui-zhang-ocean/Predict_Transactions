# %%
import numpy as np
import pandas as pd
import stats_can
from datetime import datetime

# %%
#sc = stats_can.StatsCan(data_folder = "/data/eco")
#df = sc.table_to_df("271-000-22-01")
#sc.downloaded_tables

eco_vec_map = {'CPI':'v41690973',
               'Exchange_Rate_USD':'v111666275',
               'GDP':'v65201210',
               'Unemployment_Rate':'v91506256',
               'TSX':'v122620'}

# %%
vectors = list(eco_vec_map.values())
N = 36

# %%
## check out direct json result from the API 
# stats_can.scwds.get_data_from_vectors_and_latest_n_periods(vectors, periods = N)
## retrieve and wrap up data into dataframe
# stats_can.sc.vectors_to_df(vectors, periods = N, start_release_date = None, end_release_date = None)

# %%
#now = datetime.now().strftime("%Y-%m-%dT%H:%M")
#stats_can.sc.vectors_to_df(vectors, start_release_date = "2018-09-01T08:30", end_release_date = "2020-11-10T10:31")

# %%
# retrieve last N points from Stats Canada
df = stats_can.sc.vectors_to_df(vectors, periods = N)

# %%
inv_map = {v: k for k, v in eco_vec_map.items()}
df.columns = df.columns.to_series().map(inv_map)
df.index.names = ['Date']
print(df)
# Out:
#                  TSX    CPI        GDP  Unemployment_Rate  Exchange_Rate_USD
# Date
# 2017-09-01       NaN    NaN  1905358.0                NaN                NaN
# 2017-10-01  16025.59  130.9  1907384.0                NaN                NaN
# 2017-11-01  16067.48  131.3  1917258.0                5.4             1.2769
# 2017-12-01  16209.13  130.8  1922552.0                5.3             1.2771
# 2018-01-01  15951.67  131.7  1920911.0                6.2             1.2427
# 2018-02-01  15442.68  132.5  1926421.0                6.1             1.2586
# 2018-03-01  15367.29  132.9  1931188.0                6.3             1.2932
# 2018-04-01  15607.88  133.3  1930135.0                6.1             1.2733
# 2018-05-01  16061.50  133.4  1938797.0                5.9             1.2873
# 2018-06-01  16277.73  133.6  1939974.0                5.7             1.3129
# 2018-07-01  16434.01  134.3  1945241.0                6.0             1.3130
# 2018-08-01  16262.88  134.2  1947286.0                6.6             1.3041
# 2018-09-01  16073.14  133.7  1948264.0                5.4             1.3037
# 2018-10-01  15027.28  134.1  1951927.0                5.3             1.3010
# 2018-11-01  15197.82  133.5  1947407.0                5.2             1.3200
# 2018-12-01  14322.86  133.4  1947565.0                5.2             1.3432
# 2019-01-01  15540.60  133.6  1950955.0                6.2             1.3301
# 2019-02-01  15999.01  134.5  1947760.0                6.1             1.3206
# 2019-03-01  16102.09  135.4  1960078.0                6.2             1.3368
# 2019-04-01  16580.73  136.0  1966041.0                5.9             1.3378
# 2019-05-01  16037.49  136.6  1972475.0                5.5             1.3459
# 2019-06-01  16382.20  136.3  1976566.0                5.2             1.3287
# 2019-07-01  16406.56  137.0  1977923.0                5.9             1.3101
# 2019-08-01  16442.07  136.8  1978615.0                6.3             1.3277
# 2019-09-01  16658.63  136.2  1981101.0                5.0             1.3241
# 2019-10-01  16483.16  136.6  1980913.0                5.0             1.3190
# 2019-11-01  17040.20  136.4  1981630.0                5.5             1.3239
# 2019-12-01  17063.43  136.4  1988279.0                5.1             1.3172
# 2020-01-01  17318.49  136.8  1989963.0                5.8             1.3087
# 2020-02-01  16263.05  137.4  1995120.0                5.9             1.3286
# 2020-03-01  13378.75  136.6  1849437.0                8.4             1.3953
# 2020-04-01  14780.74  135.7  1634708.0               13.5             1.4058
# 2020-05-01  15192.83  136.1  1713647.0               13.8             1.3970
# 2020-06-01  15515.22  137.2  1825876.0               11.9             1.3550
# 2020-07-01  16169.20  137.2  1881709.0               11.2             1.3499
# 2020-08-01  16514.44  137.0  1904249.0               11.0             1.3222
# 2020-09-01  16121.38  136.9        NaN                8.4             1.3228
# 2020-10-01       NaN    NaN        NaN                8.1             1.3215

# %%
df.plot(subplots = True,figsize=(14,10),layout=(4, 2));
